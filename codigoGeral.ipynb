# %%
from sklearn.datasets import load_sample_image

# %%
im_china = load_sample_image("china.jpg")

# %%
type(im_china)
# Out:
# numpy.ndarray

# %%
im_china.shape # dimensões
# Out:
# (427, 640, 3)

# %%
(427*640)*(256**3)
# Out:
# 4584877588480
